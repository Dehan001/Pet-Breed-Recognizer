# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Pet Breed Recognizer
# Out:
# /content/drive/MyDrive/Pet Breed Recognizer

# %%
version = 2
img_path = 'test_images'
model_path = f'models/pet-breed-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1

# %%
img = Image.open(f'{img_path}/unknown00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('german shepherd dog breed',
#  tensor(9),
#  tensor([1.3875e-11, 2.4473e-11, 2.4151e-13, 5.0363e-14, 1.4404e-09, 1.0845e-10,
#          2.9865e-12, 2.7211e-15, 7.8483e-14, 1.0000e+00, 4.2353e-13, 1.7001e-13,
#          1.3358e-12, 1.2235e-12, 1.0628e-13, 4.9464e-12, 3.7593e-12, 1.1080e-13,
#          1.7497e-13, 7.3873e-12, 2.3452e-13, 4.1727e-13, 2.1239e-12, 2.2594e-14,
# ...

# %% [markdown]
# # Inference 2

# %%
img = Image.open(f'{img_path}/unknown01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
model.predict(f'{img_path}/unknown01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('sphynx cat breed',
#  tensor(22),
#  tensor([2.8810e-09, 6.7922e-10, 1.4234e-07, 9.9934e-11, 2.0416e-10, 2.4529e-13,
#          1.2106e-12, 1.2057e-13, 7.2150e-10, 4.3379e-11, 1.0995e-12, 4.2221e-12,
#          1.8546e-10, 2.1758e-13, 4.1577e-14, 6.6940e-11, 1.0852e-14, 1.8108e-12,
#          4.9617e-15, 1.8906e-11, 6.3795e-12, 2.3449e-14, 1.0000e+00, 8.8691e-12,
# ...

# %% [markdown]
# # Inference 3

# %%
img = Image.open(f'{img_path}/unknown02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('syrian hamster breed',
#  tensor(23),
#  tensor([7.8149e-06, 7.0768e-06, 4.7427e-06, 1.1425e-04, 2.9213e-04, 2.3497e-02,
#          1.1101e-05, 1.1008e-01, 3.8867e-06, 6.0438e-05, 9.6888e-05, 5.0506e-05,
#          1.1692e-04, 8.8225e-05, 8.5063e-05, 7.8314e-06, 2.8849e-04, 3.5610e-05,
#          1.2417e-04, 5.3641e-05, 1.3450e-02, 3.3535e-05, 5.4657e-05, 8.2638e-01,
# ...

# %% [markdown]
# # Inference 4

# %%
img = Image.open(f'{img_path}/unknown03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('goldfish breed',
#  tensor(11),
#  tensor([3.0297e-06, 8.7694e-08, 8.7702e-09, 1.1481e-04, 4.0756e-07, 1.4601e-07,
#          3.5881e-07, 3.8667e-06, 1.0077e-07, 1.9571e-08, 2.3980e-08, 9.9987e-01,
#          3.1916e-06, 2.9974e-08, 5.1995e-08, 1.2790e-07, 9.3097e-07, 4.5636e-09,
#          1.2196e-06, 9.3223e-08, 3.8688e-06, 7.0186e-07, 4.5115e-07, 1.2149e-06,
# ...
